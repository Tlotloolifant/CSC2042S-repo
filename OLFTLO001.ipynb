# %% [markdown]
# Import libaries

# %%
import numpy as np
import matplotlib as mp
from PIL import Image 
import os

# %% [markdown]
# Loading images

# %%
data_path = "dataset"

grayscle_train_path = os.path.join(data_path, "grayscale",'train')
rgb_train_path= os.path.join(data_path, "rbg",'train')
print(grayscle_train_path)
# Out:
# dataset\grayscale\train

# %%
#testing for 1 image
image_path = "dataset/grayscale/train/bart_simpson/pic_0000.jpg"
image = Image.open(image_path)

print (image)
print(image.size)
print(image.mode)

image2_path= "dataset/rgb/train/bart_simpson/pic_0000.jpg"
image2 = Image.open(image2_path)

print(image2, image2.size, image2.mode)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=28x28 at 0x22F0F8EB110>
# (28, 28)
# L
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=28x28 at 0x22F0F8E9F70> (28, 28) RGB
